# %% [markdown]
# # Data collection and Data quality

# %% [markdown]
# ## Data collection and processing for demographic data analysis

# %% [markdown]
# ### Data Colection

# %% [markdown]
# * Import packager

# %%
# Change the dir to project root
import sys
sys.path.append("..")

# %%
import pandas as pd
import json
import geopandas as gpd
from matplotlib import pyplot as plt
import seaborn as sns
import time
import requests
import os
# %load_ext autoreload
# %autoreload 2
from src import loader, reader, saver, url_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# * Downlord data

# %%
# economic indicators: ["gdp", "gdp_per_capita", "gdp_per_capita_growth", "population" ]
economic_indicators: list[str] = ["gdp", "gdp_per_capita", "gdp_per_capita_growth", "population"]
for indicator in economic_indicators:
    url: str = url_data.get_urls("world_bank", indicator)  # type: ignore
    print(url)
    saver.save_data_request(url= url, file=f"economic_{indicator}") # type: ignore
    time.sleep(1)  # Sleep for 1 second to avoid overwhelming the server
# Out:
# https://api.worldbank.org/v2/country/all/indicator/NY.GDP.MKTP.CD?format=json&per_page=500
# Loading data from JSON response...
# Data loaded successfully from JSON.
# https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.CD?format=json&per_page=500
# Loading data from JSON response...
# Data loaded successfully from JSON.
# https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.KD.ZG?format=json&per_page=500
# Loading data from JSON response...
# Data loaded successfully from JSON.
# https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&per_page=500
# Loading data from JSON response...
# Data loaded successfully from JSON.

# %%
# public_policies_indicators: ["government_expenditure", "spending_gov", "military_expenditure", "education_expenditure"]
os.makedirs("../data/raw", exist_ok=True)  # Ensure the directory exists
public_policies_indicators: list[str] = ["government_expenditure", "spending_gov", "military_expenditure", "education_expenditure"]
for indicator in public_policies_indicators:
    url: str = url_data.get_urls("world_bank", indicator)  # type: ignore
    print(url)
    saver.save_data_request(url= url, file=f"public_policies_{indicator}") # type: ignore
    time.sleep(1)  # Sleep for 1 second to avoid overwhelming the server
# Out:
# [autoreload of src.saver failed: Traceback (most recent call last):
#   File "/Users/moloarmindo/itCareer/projetos/data_science/DemographicData/.venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/moloarmindo/itCareer/projetos/data_science/DemographicData/.venv/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Users/moloarmindo/.local/share/uv/python/cpython-3.10.19-macos-x86_64-none/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/moloarmindo/itCareer/projetos/data_science/DemographicData/notebooks/../src/saver.py", line 13, in <module>
#     from rich.abc import f
# ImportError: cannot import name 'f' from 'rich.abc' (/Users/moloarmindo/itCareer/projetos/data_science/DemographicData/.venv/lib/python3.10/site-packages/rich/abc.py)
# ]
# https://api.worldbank.org/v2/country/all/indicator/GC.XPN.TOTL.GD.ZS?format=json&per_page=500
# File '../data/raw/public_policies_government_expenditure' does not exist.
# https://api.worldbank.org/v2/country/all/indicator/GC.XPN.TOTL.GD.ZS?format=json&per_page=500
# File '../data/raw/public_policies_spending_gov' does not exist.
# https://api.worldbank.org/v2/country/all/indicator/MS.MIL.XPND.GD.ZS?format=json&per_page=500
# File '../data/raw/public_policies_military_expenditure' does not exist.
# https://api.worldbank.org/v2/country/all/indicator/SE.XPD.TOTL.GD.ZS?format=json&per_page=500
# File '../data/raw/public_policies_education_expenditure' does not exist.

# %%
os.makedirs("../data/raw", exist_ok=True)  # Ensure the directory exists
social_indicators: list[str] = ["child_mortality", "infant_mortality", "life_expectancy", "nutrition", "quality_of_education"]
for indicator in social_indicators:
    url: str = url_data.get_urls("unicef", indicator)  # type: ignore
    print(url)
    saver.save_data_request(url= url, file=f"social_{indicator}") # type: ignore
    time.sleep(4)  # Sleep for 4 seconds to avoid overwhelming the server
# Out:
# https://data.unicef.org/wp-content/uploads/2023/11/child_mortality.json
# Connection failed with status code: 404 Client Error: Not Found for url: https://data.unicef.org/wp-content/uploads/2023/11/child_mortality.json
# https://data.unicef.org/wp-content/uploads/2023/11/infant_mortality.json
# Connection failed with status code: 404 Client Error: Not Found for url: https://data.unicef.org/wp-content/uploads/2023/11/infant_mortality.json
# https://data.unicef.org/wp-content/uploads/2023/11/life_expectancy.json
# Connection failed with status code: 404 Client Error: Not Found for url: https://data.unicef.org/wp-content/uploads/2023/11/life_expectancy.json
# https://data.unicef.org/wp-content/uploads/2023/11/nutricion.json
# Connection failed with status code: 404 Client Error: Not Found for url: https://data.unicef.org/wp-content/uploads/2023/11/nutricion.json
# https://data.unicef.org/wp-content/uploads/2023/11/quality_of_education.json
# Connection failed with status code: 404 Client Error: Not Found for url: https://data.unicef.org/wp-content/uploads/2023/11/quality_of_education.json
